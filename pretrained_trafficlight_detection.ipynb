# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check PyTorch and GPU.

# %%
# Pip install method (recommended)
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.105 🚀 Python-3.10.11 torch-2.0.0+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/107.7 GB disk)

# %%
# Git clone method (for development)
# !git clone https://github.com/ultralytics/ultralytics
# %pip install -qe ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 8411, done.
# remote: Counting objects: 100% (522/522), done.
# remote: Compressing objects: 100% (306/306), done.
# remote: Total 8411 (delta 267), reused 416 (delta 216), pack-reused 7889
# Receiving objects: 100% (8411/8411), 5.98 MiB | 23.18 MiB/s, done.
# Resolving deltas: 100% (5597/5597), done.
#   Preparing metadata (setup.py) ... done

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Run the YOLOv8 Model
# Detection

# %%
# Run inference on an image with YOLOv8n

# !yolo task=detect mode=predict model=best.pt conf=0.25 source='/content/drive/MyDrive/testvideo.mp4'
# !yolo task=detect mode=predict model='/content/drive/MyDrive/color_detection/runs/detect/train2/weights/best.pt' conf=0.25 source='/content/drive/MyDrive/color_detection/testvideo.mp4' save=True
# Out:
# Ultralytics YOLOv8.0.105 🚀 Python-3.10.11 torch-2.0.0+cu118 CPU
# YOLOv8n summary (fused): 168 layers, 3006233 parameters, 0 gradients
#
# video 1/1 (1/2892) /content/drive/MyDrive/color_detection/testvideo.mp4: 384x640 (no detections), 689.6ms
# video 1/1 (2/2892) /content/drive/MyDrive/color_detection/testvideo.mp4: 384x640 1 red, 151.9ms
# video 1/1 (3/2892) /content/drive/MyDrive/color_detection/testvideo.mp4: 384x640 (no detections), 171.8ms
# video 1/1 (4/2892) /content/drive/MyDrive/color_detection/testvideo.mp4: 384x640 1 green, 1 red, 207.9ms
# video 1/1 (5/2892) /content/drive/MyDrive/color_detection/testvideo.mp4: 384x640 1 red, 208.2ms
# video 1/1 (6/2892) /content/drive/MyDrive/color_detection/testvideo.mp4: 384x640 (no detections), 222.2ms
# video 1/1 (7/2892) /content/drive/MyDrive/color_detection/testvideo.mp4: 384x640 1 red, 226.8ms
# video 1/1 (8/2892) /content/drive/MyDrive/color_detection/testvideo.mp4: 384x640 1 red, 206.4ms
# ...

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/runs/detect/predict/testvideo.mp4'

# Compressed video path
compressed_path = "/content/result_color_detection.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# Segmentation

# %%
# !yolo task=detect mode=predict model=yolov8n-seg.pt conf=0.25 source='/content/drive/MyDrive/yolov8/smoke_detection/video_1.mp4'

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/runs/segment/predict/video_1.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
